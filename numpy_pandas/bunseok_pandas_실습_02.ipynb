# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import json

import warnings
warnings.filterwarnings("ignore")

print('numpy version - ' , np.__version__)
print('pandas version - ' , pd.__version__)

def seriesinfo(s) :
    print('index - ' , s.index , type(s.index))
    print('value - ' , s.values , type(s.values))
    print()
    print('data - ')
    print(s)
    
def frminfo(df) :
    print('shape     - ' , df.shape)
    print('size      - ' , df.size)
    print('ndim      - ' , df.ndim )
    print('index     - ' , df.index   , type(df.index))
    print('col index - ' , df.columns , type(df.columns))
    print('values    - ')
    print(df.values  , '\n' , type(df.values))
    print()
    print('data - ')
    display(df)
# Out:
# numpy version -  1.21.5
# pandas version -  1.4.4

# %% [markdown]
# - 기사 원문 : https://www.news1.kr/articles/?1911504

# %%
# encoding = 'utf-8 cp949 euc-kr'
seoul_crime_frm = pd.read_csv('C:/Users/PiGiraffe0/Documents/SQL/data/test/service_data_crime_in_seoul.csv' , encoding = 'cp949')
seoul_crime_frm.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1   종로서      3      3      6      5    115     98  1,070   413  1,278  1,070
# 2  남대문서      1      0      6      4     65     46  1,153   382    869    794
# 3  서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711
# 4   혜화서      3      2      5      4     96     63  1,114   424  1,015    861

# %%
seoul_crime_frm.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1   종로서      3      3      6      5    115     98  1,070   413  1,278  1,070
# 2  남대문서      1      0      6      4     65     46  1,153   382    869    794
# 3  서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711
# 4   혜화서      3      2      5      4     96     63  1,114   424  1,015    861

# %%
# conda install googlemaps
import googlemaps

# %%
gmaps = googlemaps.Client(key = 'AIzaSyBQy1nRN8F9UbiMiWRagzHdhsyy5Dc8dv0')
gmaps

# %%
gmaps.geocode('중부서' , language = 'ko')
# Out:
# [{'address_components': [{'long_name': '２７',
#     'short_name': '２７',
#     'types': ['premise']},
#    {'long_name': '수표로',
#     'short_name': '수표로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '중구',
#     'short_name': '중구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '100-032',
#     'short_name': '100-032',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 중구 수표로 27',
#   'geometry': {'location': {'lat': 37.56361709999999, 'lng': 126.9896517},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5649660802915,
#      'lng': 126.9910006802915},
#     'southwest': {'lat': 37.5622681197085, 'lng': 126.9883027197085}}},
# ...

# %%
# 관서명이 **서로 이므로 주소 검색에 문제가 발생
# 관서명을 서울**경찰서로 변경
gmaps.geocode('혜화서' , language = 'ko')
# Out:
# []

# %%
seoul_crime_frm['관서명'][0].find('서')
# Out:
# 2

# %%
'서울' + seoul_crime_frm['관서명'][0][0:seoul_crime_frm['관서명'][0].find('서')] + '경찰서'
# Out:
# '서울중부경찰서'

# %%
station_name_lst = []
for i in range(len(seoul_crime_frm)) :
    station_name_lst.append('서울' + seoul_crime_frm['관서명'][i][0:seoul_crime_frm['관서명'][i].find('서')] + '경찰서')
    
station_name_lst
# Out:
# ['서울중부경찰서',
#  '서울종로경찰서',
#  '서울남대문경찰서',
#  '서울경찰서',
#  '서울혜화경찰서',
#  '서울용산경찰서',
#  '서울성북경찰서',
#  '서울동대문경찰서',
#  '서울마포경찰서',
#  '서울영등포경찰서',
#  '서울성동경찰서',
#  '서울동작경찰서',
#  '서울광진경찰서',
#  '서울경찰서',
#  '서울강북경찰서',
#  '서울금천경찰서',
#  '서울중랑경찰서',
#  '서울강남경찰서',
#  '서울관악경찰서',
#  '서울강경찰서',
#  '서울강동경찰서',
#  '서울종암경찰서',
#  '서울구로경찰서',
#  '서울경찰서',
#  '서울양천경찰서',
#  '서울송파경찰서',
#  '서울노원경찰서',
#  '서울방배경찰서',
#  '서울은평경찰서',
#  '서울도봉경찰서',
#  '서울수경찰서']

# %%
station_name_lst = []
for i in seoul_crime_frm['관서명'] :
    station_name_lst.append('서울'+i[:-1]+'경찰서')

station_name_lst
# Out:
# ['서울중부경찰서',
#  '서울종로경찰서',
#  '서울남대문경찰서',
#  '서울서대문경찰서',
#  '서울혜화경찰서',
#  '서울용산경찰서',
#  '서울성북경찰서',
#  '서울동대문경찰서',
#  '서울마포경찰서',
#  '서울영등포경찰서',
#  '서울성동경찰서',
#  '서울동작경찰서',
#  '서울광진경찰서',
#  '서울서부경찰서',
#  '서울강북경찰서',
#  '서울금천경찰서',
#  '서울중랑경찰서',
#  '서울강남경찰서',
#  '서울관악경찰서',
#  '서울강서경찰서',
#  '서울강동경찰서',
#  '서울종암경찰서',
#  '서울구로경찰서',
#  '서울서초경찰서',
#  '서울양천경찰서',
#  '서울송파경찰서',
#  '서울노원경찰서',
#  '서울방배경찰서',
#  '서울은평경찰서',
#  '서울도봉경찰서',
#  '서울수서경찰서']

# %%
gmaps.geocode(station_name_lst[0] , language = 'ko')[0].get('geometry')['location']['lat']
gmaps.geocode(station_name_lst[0] , language = 'ko')[0].get('geometry')['location']['lng']
# Out:
# 126.9896517

# %%
gmaps.geocode(station_name_lst[0] , language = 'ko')[0].get('formatted_address')
# Out:
# '대한민국 서울특별시 중구 수표로 27'

# %%
# 경찰서 이름의 풀 주소와 위도 , 경도를 구해보자.

# %%
station_address = []
station_lat = []
station_lng = []

# %%
station_address = []
station_lat = []
station_lng = []

for i in station_name_lst :
    station_address.append(gmaps.geocode(i , language = 'ko')[0].get('formatted_address'))
    station_lat.append(gmaps.geocode(i , language = 'ko')[0].get('geometry')['location']['lat'])
    station_lng.append(gmaps.geocode(i , language = 'ko')[0].get('geometry')['location']['lng'])

station_lat
station_lng
len(station_address)
# Out:
# 31

# %%
len(station_lng)
# Out:
# 31

# %%
len(station_address)
# Out:
# 31

# %%
seoul_crime_frm['관서명'].unique()
# Out:
# array(['중부서', '종로서', '남대문서', '서대문서', '혜화서', '용산서', '성북서', '동대문서', '마포서',
#        '영등포서', '성동서', '동작서', '광진서', '서부서', '강북서', '금천서', '중랑서', '강남서',
#        '관악서', '강서서', '강동서', '종암서', '구로서', '서초서', '양천서', '송파서', '노원서',
#        '방배서', '은평서', '도봉서', '수서서'], dtype=object)

# %%
# 구별 칼럼 추가 - station_address 이용

# %%
station_address
# Out:
# ['대한민국 서울특별시 중구 수표로 27',
#  '대한민국 서울특별시 종로구 인사동5길 41',
#  '대한민국 서울특별시 중구 한강대로 410',
#  '대한민국 서울특별시 서대문구 통일로 113',
#  '대한민국 서울특별시 종로구 창경궁로 112-16',
#  '대한민국 서울특별시 용산구 백범로 329',
#  '대한민국 서울특별시 성북구 삼선동 보문로 170',
#  '대한민국 서울특별시 동대문구 약령시로21길 29',
#  '대한민국 서울특별시 마포구 마포대로 183',
#  '대한민국 서울특별시 영등포구 국회대로 608',
#  '대한민국 서울특별시 성동구 행당동 왕십리광장로 9',
#  '대한민국 서울특별시 동작구 노량진로 148',
#  '대한민국 서울특별시 광진구 구의동 자양로 167',
#  '대한민국 서울특별시 은평구 진흥로 58',
#  '대한민국 서울특별시 강북구 오패산로 406',
#  '대한민국 서울특별시 금천구 시흥대로73길 50',
#  '대한민국 서울특별시 중랑구 묵2동 249-2',
#  '대한민국 서울특별시 강남구 테헤란로114길 11',
#  '대한민국 서울특별시 관악구 관악로5길 33',
#  '대한민국 서울특별시 양천구 신월동 화곡로 73',
#  '대한민국 서울특별시 강동구 성내로 57',
#  '대한민국 서울특별시 성북구 종암로 135',
#  '대한민국 서울특별시 구로구 가마산로 235',
#  '대한민국 서울특별시 서초구 서초3동 반포대로 179',
#  '대한민국 서울특별시 양천구 목동동로 99',
#  '대한민국 서울특별시 송파구 중대로 221',
#  '대한민국 서울특별시 노원구 노원로 283',
#  '대한민국 서울특별시 서초구 동작대로 204',
#  '대한민국 서울특별시 은평구 연서로 365',
#  '대한민국 서울특별시 도봉구 노해로 403',
#  '대한민국 서울특별시 강남구 개포로 617']

# %%
# 중복 확인
# dup = df.duplicated(['columns'])

# %%
lst = []
for i in range(len(station_address)):
    lst.append(station_address[i].split(' ')[2])
seoul_crime_frm['지역구'] = lst
seoul_crime_frm
# Out:
#      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 0    중부서      2      2      3      2    105     65  1,395    477  1,355
# 1    종로서      3      3      6      5    115     98  1,070    413  1,278
# 2   남대문서      1      0      6      4     65     46  1,153    382    869
# 3   서대문서      2      2      5      4    154    124  1,812    738  2,056
# 4    혜화서      3      2      5      4     96     63  1,114    424  1,015
# 5    용산서      5      5     14     14    194    173  1,557    587  2,050
# 6    성북서      2      2      2      1     86     71    953    409  1,194
# 7   동대문서      5      5     13     13    173    146  1,981    814  2,548
# 8    마포서      8      8     14     10    294    247  2,555    813  2,983
# 9   영등포서     14     12     22     20    295    183  2,964    978  3,572
# 10   성동서      4      4      9      8    126    119  1,607    597  1,612
# 11   동작서      5      5      9      5    285    139  1,865    661  1,910
# ...

# %%
for i in range(31) :
    if seoul_crime_frm.duplicated(['지역구'])[i] == True :
        print(seoul_crime_frm['관서명'][i])
# Out:
# 남대문서
# 혜화서
# 종암서
# 양천서
# 방배서
# 은평서
# 수서서

# %%
# 파일 저장하기
# utf-8 인코딩시 한글이 깨진다.(파일 오픈시)
# cp949 인코딩으로 저장하자.
# index = False 인덱스가 추가되는 것을 막아준다.

seoul_crime_frm.to_csv('C:/Users/PiGiraffe0/Documents/SQL/data/test/seoul_crime_frm.csv' , encoding='cp949' ,
                      index = False)

# %%
seoul_crime_frm = pd.read_csv('C:/Users/PiGiraffe0/Documents/SQL/data/test/seoul_crime_frm.csv' 
                              , encoding='cp949' 
                              , thousands = ',')
seoul_crime_frm
# Out:
#      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 0    중부서      2      2      3      2    105     65   1395    477   1355
# 1    종로서      3      3      6      5    115     98   1070    413   1278
# 2   남대문서      1      0      6      4     65     46   1153    382    869
# 3   서대문서      2      2      5      4    154    124   1812    738   2056
# 4    혜화서      3      2      5      4     96     63   1114    424   1015
# 5    용산서      5      5     14     14    194    173   1557    587   2050
# 6    성북서      2      2      2      1     86     71    953    409   1194
# 7   동대문서      5      5     13     13    173    146   1981    814   2548
# 8    마포서      8      8     14     10    294    247   2555    813   2983
# 9   영등포서     14     12     22     20    295    183   2964    978   3572
# 10   성동서      4      4      9      8    126    119   1607    597   1612
# 11   동작서      5      5      9      5    285    139   1865    661   1910
# ...

# %%
#  범죄 데이터를 구별로 정리하자.
# pivot_table을 사용해서 관서별에서 구별로 바꿔보자.

# %%
seoul_crime_frm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   관서명     31 non-null     object
#  1   살인 발생   31 non-null     int64
#  2   살인 검거   31 non-null     int64
#  3   강도 발생   31 non-null     int64
#  4   강도 검거   31 non-null     int64
#  5   강간 발생   31 non-null     int64
#  6   강간 검거   31 non-null     int64
#  7   절도 발생   31 non-null     object
#  8   절도 검거   31 non-null     object
#  9   폭력 발생   31 non-null     object
#  10  폭력 검거   31 non-null     object
#  11  지역구     31 non-null     object
# dtypes: int64(6), object(6)
# memory usage: 3.0+ KB

# %%
result_frm = sex_class_category_subset.pivot_table(index = ['sex' , 'age_category'] , columns = 'class' , values = 'survived' , 
                       aggfunc = 'count' , 
                       margins = True ,
                       margins_name = 'survived_ratio')

# %%
seoul_crime_frm.pivot_table(index = ['지역구'])
# Out:
#       강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생
# 지역구
# 강남구   174.5  224.5    9.0   10.5    5.0    6.5
# 강동구   123.0  156.0    8.0    6.0    3.0    4.0
# 강북구   126.0  153.0   13.0   14.0    8.0    7.0
# 관악구   221.0  320.0   14.0   12.0    8.0    9.0
# 광진구   220.0  240.0   26.0   14.0    4.0    4.0
# 구로구   164.0  281.0   11.0   15.0    6.0    8.0
# 금천구   122.0  151.0    6.0    6.0    4.0    3.0
# 노원구   121.0  197.0    7.0    7.0   10.0   10.0
# 도봉구   106.0  102.0   10.0    9.0    3.0    3.0
# 동대문구  146.0  173.0   13.0   13.0    5.0    5.0
# 동작구   139.0  285.0    5.0    9.0    5.0    5.0
# 마포구   247.0  294.0   10.0   14.0    8.0    8.0
# 서대문구  124.0  154.0    4.0    5.0    2.0    2.0
# 서초구   124.5  196.5    3.0    4.5    3.0    4.0
# 성동구   119.0  126.0    8.0    9.0    4.0    4.0
# 성북구    62.0   75.0    2.0    2.5    2.5    2.5
# 송파구   178.0  220.0   10.0   13.0   10.0   11.0
# 양천구   148.0  191.0    8.0    9.5    6.5    5.0
# 영등포구  183.0  295.0   20.0   22.0   12.0   14.0
# ...

# %%
# 범죄별 검거율을 계산하여 검거 건수를 검거율로 대체

# %%
seoul_crime_frm['살인 검거율'] = round(seoul_crime_frm['살인 검거'] / seoul_crime_frm['살인 발생'] * 100 , 2)
seoul_crime_frm['절도 검거율'] = round(seoul_crime_frm['절도 검거'] / seoul_crime_frm['절도 발생'] * 100 , 2)
seoul_crime_frm['강도 검거율'] = round(seoul_crime_frm['강도 검거'] / seoul_crime_frm['강도 발생'] * 100 , 2)
seoul_crime_frm['강간 검거율'] = round(seoul_crime_frm['강간 검거'] / seoul_crime_frm['강간 발생'] * 100 , 2)
seoul_crime_frm['폭력 검거율'] = round(seoul_crime_frm['폭력 검거'] / seoul_crime_frm['폭력 발생'] * 100 , 2)

# %%
seoul_crime_pivot_frm = seoul_crime_frm.pivot_table(index = ['지역구'])

# %%
del seoul_crime_pivot_frm['살인 검거']
del seoul_crime_pivot_frm['절도 검거']
del seoul_crime_pivot_frm['강도 검거']
del seoul_crime_pivot_frm['강간 검거']
del seoul_crime_pivot_frm['폭력 검거']

# %%
seoul_crime_pivot_frm[seoul_crime_pivot_frm > 100]
# Out:
#       강간 검거율  강간 발생  강도 검거율  강도 발생  살인 검거율  살인 발생  절도 검거율   절도 발생  폭력 검거율  \
# 지역구
# 강남구      NaN  224.5     NaN    NaN     NaN    NaN     NaN  1925.0     NaN
# 강동구      NaN  156.0  133.33    NaN     NaN    NaN     NaN  2366.0     NaN
# 강북구      NaN  153.0     NaN    NaN  114.29    NaN     NaN  1434.0     NaN
# 관악구      NaN  320.0  116.67    NaN     NaN    NaN     NaN  2706.0     NaN
# 광진구      NaN  240.0  185.71    NaN     NaN    NaN     NaN  3026.0     NaN
# 구로구      NaN  281.0     NaN    NaN     NaN    NaN     NaN  2335.0     NaN
# 금천구      NaN  151.0     NaN    NaN  133.33    NaN     NaN  1567.0     NaN
# 노원구      NaN  197.0     NaN    NaN     NaN    NaN     NaN  2193.0     NaN
# 도봉구   103.92  102.0  111.11    NaN     NaN    NaN     NaN  1063.0     NaN
# 동대문구     NaN  173.0     NaN    NaN     NaN    NaN     NaN  1981.0     NaN
# 동작구      NaN  285.0     NaN    NaN     NaN    NaN     NaN  1865.0     NaN
# 마포구      NaN  294.0     NaN    NaN     NaN    NaN     NaN  2555.0     NaN
# ...

# %%
cols = ['강간 검거율' , '강도 검거율' , '살인 검거율' , '절도 검거율' , '폭력 검거율']
for col in cols : 
    seoul_crime_pivot_frm[col][seoul_crime_pivot_frm[col]>100] = 100

# %%
seoul_crime_pivot_frm['강간 검거율']==100
# Out:
# 지역구
# 강남구     False
# 강동구     False
# 강북구     False
# 관악구     False
# 광진구     False
# 구로구     False
# 금천구     False
# 노원구     False
# 도봉구      True
# 동대문구    False
# 동작구     False
# 마포구     False
# 서대문구    False
# 서초구     False
# 성동구     False
# 성북구     False
# 송파구     False
# 양천구     False
# 영등포구    False
# 용산구     False
# 은평구     False
# 종로구     False
# 중구      False
# 중랑구     False
# Name: 강간 검거율, dtype: bool

# %%
seoul_crime_pivot_frm
# Out:
#        강간 검거율  강간 발생   강도 검거율  강도 발생   살인 검거율  살인 발생  절도 검거율   절도 발생  폭력 검거율  \
# 지역구
# 강남구    79.110  224.5   90.000   10.5   85.000    6.5  43.545  1925.0  86.385
# 강동구    78.850  156.0  100.000    6.0   75.000    4.0  33.350  2366.0  82.890
# 강북구    82.350  153.0   92.860   14.0  100.000    7.0  43.100  1434.0  88.640
# 관악구    69.060  320.0  100.000   12.0   88.890    9.0  30.560  2706.0  80.110
# 광진구    91.670  240.0  100.000   14.0  100.000    4.0  42.200  3026.0  83.050
# 구로구    58.360  281.0   73.330   15.0   75.000    8.0  38.070  2335.0  80.880
# 금천구    80.790  151.0  100.000    6.0  100.000    3.0  56.670  1567.0  86.470
# 노원구    61.420  197.0  100.000    7.0  100.000   10.0  36.530  2193.0  85.530
# 도봉구   100.000  102.0  100.000    9.0  100.000    3.0  44.970  1063.0  87.630
# 동대문구   84.390  173.0  100.000   13.0  100.000    5.0  41.090  1981.0  87.400
# 동작구    48.770  285.0   55.560    9.0  100.000    5.0  35.440  1865.0  83.090
# ...

# %%
# 특정 문자가 들어간 칼럼 찾기
# .filter(regex='검거율')

# seoul_crime_pivot_table.filter(regex='검거율')[seoul_crime_pivot_table.filter(regex='검거율')>100]

# %%
# ** 발생 rename

# %%
loop = ['강간' , '강도' , '살인' , '폭력' , '절도']
for i in loop :
    seoul_crime_pivot_frm.rename(columns = {i + ' 발생' : i} , inplace = True)
    
seoul_crime_pivot_frm
# Out:
#        강간 검거율     강간   강도 검거율    강도   살인 검거율    살인  절도 검거율      절도  폭력 검거율  \
# 지역구
# 강남구    79.110  224.5   90.000  10.5   85.000   6.5  43.545  1925.0  86.385
# 강동구    78.850  156.0  100.000   6.0   75.000   4.0  33.350  2366.0  82.890
# 강북구    82.350  153.0   92.860  14.0  100.000   7.0  43.100  1434.0  88.640
# 관악구    69.060  320.0  100.000  12.0   88.890   9.0  30.560  2706.0  80.110
# 광진구    91.670  240.0  100.000  14.0  100.000   4.0  42.200  3026.0  83.050
# 구로구    58.360  281.0   73.330  15.0   75.000   8.0  38.070  2335.0  80.880
# 금천구    80.790  151.0  100.000   6.0  100.000   3.0  56.670  1567.0  86.470
# 노원구    61.420  197.0  100.000   7.0  100.000  10.0  36.530  2193.0  85.530
# 도봉구   100.000  102.0  100.000   9.0  100.000   3.0  44.970  1063.0  87.630
# 동대문구   84.390  173.0  100.000  13.0  100.000   5.0  41.090  1981.0  87.400
# 동작구    48.770  285.0   55.560   9.0  100.000   5.0  35.440  1865.0  83.090
# ...

# %%
seoul_crime_pivot_frm.filter(regex='검거율')[seoul_crime_pivot_frm.filter(regex='검거율')==100]
# Out:
#       강간 검거율  강도 검거율  살인 검거율  절도 검거율  폭력 검거율
# 지역구
# 강남구      NaN     NaN     NaN     NaN     NaN
# 강동구      NaN   100.0     NaN     NaN     NaN
# 강북구      NaN     NaN   100.0     NaN     NaN
# 관악구      NaN   100.0     NaN     NaN     NaN
# 광진구      NaN   100.0   100.0     NaN     NaN
# 구로구      NaN     NaN     NaN     NaN     NaN
# 금천구      NaN   100.0   100.0     NaN     NaN
# 노원구      NaN   100.0   100.0     NaN     NaN
# 도봉구    100.0   100.0   100.0     NaN     NaN
# 동대문구     NaN   100.0   100.0     NaN     NaN
# 동작구      NaN     NaN   100.0     NaN     NaN
# 마포구      NaN     NaN   100.0     NaN     NaN
# 서대문구     NaN     NaN   100.0     NaN     NaN
# 서초구      NaN     NaN   100.0     NaN     NaN
# 성동구      NaN     NaN   100.0     NaN     NaN
# 성북구      NaN     NaN   100.0     NaN     NaN
# 송파구      NaN     NaN     NaN     NaN     NaN
# 양천구      NaN     NaN   100.0     NaN     NaN
# 영등포구     NaN     NaN     NaN     NaN     NaN
# 용산구      NaN   100.0   100.0     NaN     NaN
# ...

# %%
seoul_crime_pivot_frm[seoul_crime_pivot_frm.filter(regex='검거율') >100] = 100
seoul_crime_pivot_frm
# Out:
#        강간 검거율     강간   강도 검거율    강도   살인 검거율    살인  절도 검거율      절도  폭력 검거율  \
# 지역구
# 강남구    79.110  224.5   90.000  10.5   85.000   6.5  43.545  1925.0  86.385
# 강동구    78.850  156.0  100.000   6.0   75.000   4.0  33.350  2366.0  82.890
# 강북구    82.350  153.0   92.860  14.0  100.000   7.0  43.100  1434.0  88.640
# 관악구    69.060  320.0  100.000  12.0   88.890   9.0  30.560  2706.0  80.110
# 광진구    91.670  240.0  100.000  14.0  100.000   4.0  42.200  3026.0  83.050
# 구로구    58.360  281.0   73.330  15.0   75.000   8.0  38.070  2335.0  80.880
# 금천구    80.790  151.0  100.000   6.0  100.000   3.0  56.670  1567.0  86.470
# 노원구    61.420  197.0  100.000   7.0  100.000  10.0  36.530  2193.0  85.530
# 도봉구   100.000  102.0  100.000   9.0  100.000   3.0  44.970  1063.0  87.630
# 동대문구   84.390  173.0  100.000  13.0  100.000   5.0  41.090  1981.0  87.400
# 동작구    48.770  285.0   55.560   9.0  100.000   5.0  35.440  1865.0  83.090
# ...
