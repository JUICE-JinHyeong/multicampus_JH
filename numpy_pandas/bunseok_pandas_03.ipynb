# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

print('numpy version - ' , np.__version__)
print('pandas version - ' , pd.__version__)
# Out:
# numpy version -  1.21.5
# pandas version -  1.4.2

# %%
def frminfo(df) :
    print('shape     - ' , df.shape)
    print('size      - ' , df.size)
    print('ndim      - ' , df.ndim )
    print('index     - ' , df.index   , type(df.index))
    print('col index - ' , df.columns , type(df.columns))
    print('values    - ')
    print(df.values  , '\n' , type(df.values))
    print()
    print('data - ')
    display(df)

# %%
def seriesinfo(s) :
    print('index - ' , s.index , type(s.index))
    print('value - ' , s.values , type(s.values))
    print()
    print('data - ')
    print(s)

# %% [markdown]
# 파일입출력과 병합, 문자열 관련된 데이터 조작
# - csv , excel , json , html , scraping 비정형 데이터의 종류
# - read_xxxx() , to_xxxx()

# %%
# csv 파일 읽기

file_path = 'C:/Users/a/Documents/SQL/data/pandas/read_csv_sample.csv'

# 기본(헤더 있음)
# sample_frm = pd.read_csv(file_path)

# 헤더 없음
# sample_frm = pd.read_csv(file_path , header = None)

# index에 칼럼 이름 생성
sample_frm = pd.read_csv(file_path , index_col = 'c4')


print('type - ' , type(sample_frm))
frminfo(sample_frm)
# Out:
# type -  <class 'pandas.core.frame.DataFrame'>
# shape     -  (3, 4)
# size      -  12
# ndim      -  2
# index     -  Int64Index([6, 4, 2], dtype='int64', name='c4') <class 'pandas.core.indexes.numeric.Int64Index'>
# col index -  Index(['c0', 'c1', 'c2', 'c3'], dtype='object') <class 'pandas.core.indexes.base.Index'>
# values    -
# [[0 1 4 7]
#  [1 2 5 8]
#  [2 3 6 9]]
#  <class 'numpy.ndarray'>
#
# data -
#     c0  c1  c2  c3
# c4
# 6    0   1   4   7
# 4    1   2   5   8
# 2    2   3   6   9

# %%
# excel 파일 읽기

file_path = 'C:/Users/a/Documents/SQL/data/pandas/남북한발전전력량.xlsx'

sample_frm = pd.read_excel(file_path)

# 헤더 x
# sample_frm = pd.read_excel(file_path , header = None)

# 다중 index 표현에 의해 Nan이 들어간다.

frminfo(sample_frm)
# Out:
# shape     -  (9, 29)
# size      -  261
# ndim      -  2
# index     -  RangeIndex(start=0, stop=9, step=1) <class 'pandas.core.indexes.range.RangeIndex'>
# col index -  Index(['전력량 (억㎾h)', '발전 전력별', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016'],
#       dtype='object') <class 'pandas.core.indexes.base.Index'>
# values    -
# [['남한' '합계' 1077 1186 1310 1444 1650 1847 2055 2244 2153 2393 2664 2852
#   3065 3225 3421 3646 3812 4031 4224 4336 4747 4969 5096 5171 5220 5281
#   5404]
#  [nan '수력' 64 51 49 60 41 55 52 54 61 61 56 42 53 69 59 52 52 50 56 56 65
#   78 77 84 78 58 66]
#  [nan '화력' 484 573 696 803 1022 1122 1264 1420 1195 1302 1518 1689 1821
#   1859 2056 2127 2272 2551 2658 2802 3196 3343 3430 3581 3427 3402 3523]
# ...

# %%
# json 파일 읽기
# json 파일은 딕셔너리 형태로 이루어져있다.
# 딕셔너리 형태의 json 파일의 key값은 칼럼, value값은 데이터이다.

file_path = 'C:/Users/a/Documents/SQL/data/pandas/read_json_sample.json'

sample_frm = pd.read_json(file_path)
frminfo(sample_frm)
# Out:
# shape     -  (3, 4)
# size      -  12
# ndim      -  2
# index     -  Index(['pandas', 'NumPy', 'matplotlib'], dtype='object') <class 'pandas.core.indexes.base.Index'>
# col index -  Index(['name', 'year', 'developer', 'opensource'], dtype='object') <class 'pandas.core.indexes.base.Index'>
# values    -
# [['' 2008 'Wes Mckinneye' 'True']
#  ['' 2006 'Travis Oliphant' 'True']
#  ['' 2003 'John D. Hunter' 'True']]
#  <class 'numpy.ndarray'>
#
# data -
#            name  year        developer opensource
# pandas           2008    Wes Mckinneye       True
# NumPy            2006  Travis Oliphant       True
# matplotlib       2003   John D. Hunter       True

# %%
# html 파일 읽기
# 패키지나 라이브러리 미설치시 오류가 날수도 있다.
# conda install ['찾을 패키지 or 라이브러리명']
# html5lib
# -> conda install -c anaconda html5lib
# anconda 홈페이지에서 다운
# conda prompt에서 관리자권한으로 싱행 후, 패키지 설치


file_path = 'C:/Users/a/Documents/SQL/data/pandas/sample.html'

# 테이블이 리스트 형식으로 들어온다.

sample_tables = pd.read_html(file_path)
print()
print('type - ' , type(sample_tables))
print('len  - ' , len(sample_tables))
print()
for idx in range(len(sample_tables)) :
    print('table index - ' , idx)
    print(sample_tables[idx])
    
sample_frm = sample_tables[1]

print()
# dataframe 으로 변환 가능\
print('type - ' ,type(sample_frm))
sample_frm.set_index('name' , inplace=True)
print(sample_frm)
# Out:
# type -  <class 'list'>
# len  -  2
#
# table index -  0
#    Unnamed: 0  c0  c1  c2  c3
# 0           0   0   1   4   7
# 1           1   1   2   5   8
# 2           2   2   3   6   9
# table index -  1
#          name  year        developer  opensource
# 0       NumPy  2006  Travis Oliphant        True
# 1  matplotlib  2003   John D. Hunter        True
# 2      pandas  2008    Wes Mckinneye        True
#
# type -  <class 'pandas.core.frame.DataFrame'>
#             year        developer  opensource
# name
# NumPy       2006  Travis Oliphant        True
# matplotlib  2003   John D. Hunter        True
# pandas      2008    Wes Mckinneye        True

# %% [markdown]
# - scraping 통한 데이터 로딩
# - BeautifulSoup(정적페이지)

# %%
from bs4 import BeautifulSoup
import requests
# 정규표현식
import re

# %%
# 크롤링
# requests.get(리퀘스트 신청 : 성공시 <Response []>)
# requests.text(리퀘스트 신청한 데이터 가져오기)

response = requests.get('https://en.wikipedia.org/wiki/List_of_American_exchange-traded_funds')
print('response - ' , response)
print()
print('response - ' , response.text)
# 객체형식으로 조작이 가능한 라이브러리가 필요하다 -> BeautifulSoup
# Out:
# response -  <Response [200]>
#
# response -  <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of American exchange-traded funds - Wikipedia</title>
# ...

# %%
soup = BeautifulSoup(response.text)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of American exchange-traded funds - Wikipedia</title>
# ...

# %%
# 특정 태그에 접근이 가능해진다.
# > 자손
# 리스트 안에 들어있다. -> 반복구문 가능

soup.select('div > ul > li')
# Out:
# [<li class="toclevel-1 tocsection-1"><a href="#Stock_ETFs"><span class="tocnumber">1</span> <span class="toctext">Stock ETFs</span></a>
#  <ul>
#  <li class="toclevel-2 tocsection-2"><a href="#Broad_market_ETFs"><span class="tocnumber">1.1</span> <span class="toctext">Broad market ETFs</span></a></li>
#  <li class="toclevel-2 tocsection-3"><a href="#Index-tracking_ETFs"><span class="tocnumber">1.2</span> <span class="toctext">Index-tracking ETFs</span></a></li>
#  <li class="toclevel-2 tocsection-4"><a href="#Style_ETFs"><span class="tocnumber">1.3</span> <span class="toctext">Style ETFs</span></a>
#  <ul>
#  <li class="toclevel-3 tocsection-5"><a href="#Large-cap_ETFs"><span class="tocnumber">1.3.1</span> <span class="toctext">Large-cap ETFs</span></a></li>
#  <li class="toclevel-3 tocsection-6"><a href="#Mid-cap_ETFs"><span class="tocnumber">1.3.2</span> <span class="toctext">Mid-cap ETFs</span></a></li>
# ...

# %%
# 타입은 bs4 의 요소 결과 집합이다.

print('type - ' , type(soup.select('div > ul > li')))
# Out:
# type -  <class 'bs4.element.ResultSet'>

# %%
# 반복구문으로 데이터 꺼내오기
# 아래와 같은 방식으로 데이터를 가져오고 dataframe으로 변환한다.

print('type - ' , type(soup.select('div > ul > li')))
soup.select('div > ul > li')
lst = soup.select('div > ul > li')
for row in lst :
    print(row.text)
    print('-'*100)
# Out:
# type -  <class 'bs4.element.ResultSet'>
# 1 Stock ETFs
#
# 1.1 Broad market ETFs
# 1.2 Index-tracking ETFs
# 1.3 Style ETFs
#
# 1.3.1 Large-cap ETFs
# 1.3.2 Mid-cap ETFs
# 1.3.3 Small-cap ETFs
#
#
# 1.4 International ETFs
#
# 1.4.1 Broad ex-US ETFs
# 1.4.2 Regional ex-US ETFs
# 1.4.3 Country ETFs
#
# 1.4.3.1 Developed ex-US markets
# 1.4.3.2 Emerging markets
#
#
#
#
# 1.5 Sector ETFs
#
# 1.5.1 US domestic sectors
# 1.5.2 Global sectors
#
#
#
#
# ----------------------------------------------------------------------------------------------------
# 2 Bond ETFs
# ----------------------------------------------------------------------------------------------------
# 3 Commodity ETFs
#
# 3.1 Broad basket
# 3.2 Agricultural ETFs
# 3.3 Energy commodity ETFs
# 3.4 Industrial commodity ETFs
# 3.5 Precious metals ETFs
#
#
# ----------------------------------------------------------------------------------------------------
# 4 Real estate ETFs
# ...

# %%
# 정규 표현식 함수로 내가 원하는 데이터 찾기
# etf_name = re.findal('pattern' , row.text)

# %%
lst = soup.select('div > ul > li')
for row in lst :
    print(row.text)
    etf_name = re.findall('^(.*) \(NYSE' , row.text)
    # print(etf_name)
    # etf_market = re.findall('NYSE Arca\|(.*)\)' , row.text)
    print(etf_market)
    print('-'*100)
# Out:
# 1 Stock ETFs
#
# 1.1 Broad market ETFs
# 1.2 Index-tracking ETFs
# 1.3 Style ETFs
#
# 1.3.1 Large-cap ETFs
# 1.3.2 Mid-cap ETFs
# 1.3.3 Small-cap ETFs
#
#
# 1.4 International ETFs
#
# 1.4.1 Broad ex-US ETFs
# 1.4.2 Regional ex-US ETFs
# 1.4.3 Country ETFs
#
# 1.4.3.1 Developed ex-US markets
# 1.4.3.2 Emerging markets
#
#
#
#
# 1.5 Sector ETFs
#
# 1.5.1 US domestic sectors
# 1.5.2 Global sectors
#
#
#
#
# []
# ----------------------------------------------------------------------------------------------------
# 2 Bond ETFs
# []
# ----------------------------------------------------------------------------------------------------
# 3 Commodity ETFs
#
# 3.1 Broad basket
# 3.2 Agricultural ETFs
# 3.3 Energy commodity ETFs
# 3.4 Industrial commodity ETFs
# 3.5 Precious metals ETFs
#
#
# []
# ----------------------------------------------------------------------------------------------------
# 4 Real estate ETFs
# []
# ...

# %%
- google 지오코딩
- conda install -c conda-forge googlemaps

# %%
import googlemaps

# %%
maps = googlemaps.Client(key = 'AIzaSyBQy1nRN8F9UbiMiWRagzHdhsyy5Dc8dv0')
location = maps.geocode('서울시청')
print('location - ' , type(location))
print()
print('location - ' , location[0].get('geometry')['bounds'])
print()
print('location - ' , location[0].get('geometry')['location']['lat'])
print('location - ' , location[0].get('geometry')['location']['lng'])
# Out:
# location -  <class 'list'>
#
# location -  {'northeast': {'lat': 37.7017495, 'lng': 127.1835899}, 'southwest': {'lat': 37.4259627, 'lng': 126.7645827}}
#
# location -  37.566535
# location -  126.9779692

# %% [markdown]
# 문) places = ['서울시청' , '해운대해수욕장' , '국립대전현충원' , '한라산' , '인천국제공항']

# %%
places = ['서울시청' , '해운대해수욕장' , '국립대전현충원' , '한라산' , '인천국제공항']

lst = []

for place in places :
    location = maps.geocode(place)
    lst.append([place , location[0].get('geometry')['location']['lat'] , location[0].get('geometry')['location']['lng']])
    
place_df = pd.DataFrame(lst , columns = ['지역' , '위도' , '경도'])
place_df
    

# place_df_s = place_df.transpose().rename(columns = place_df.transpose().loc['지역']).drop('지역' , axis = 0)
# place_df_s
# Out:
#         지역         위도          경도
# 0     서울시청  37.566535  126.977969
# 1  해운대해수욕장  35.158698  129.160384
# 2  국립대전현충원  36.368602  127.296685
# 3      한라산  33.361667  126.529167
# 4   인천국제공항  37.460191  126.440696

# %%
place_df.set_index('지역' , inplace = True)
place_df
# Out:
#                 위도          경도
# 지역
# 서울시청     37.566535  126.977969
# 해운대해수욕장  35.158698  129.160384
# 국립대전현충원  36.368602  127.296685
# 한라산      33.361667  126.529167
# 인천국제공항   37.460191  126.440696

# %% [markdown]
# 프레임 병합
# - pd.merge()  : 공통의 열을 기준으로 병합
# - frm.join()  : 인덱스 기준으로 병합
# - pd.concat()    : 연결

# %% [markdown]
# - 컬럼 인덱스가 다른 경우
# - 속성 : left_on = right_on

# %%
data01 = {
    '학번' : [1, 2, 3, 4] , 
    '이름' : ['하나' , '두나' , '세나' , '네나'] ,
    '학년' : [2, 4, 1, 3] 
}

data02 = {
    '과목코드' : [1, 2, 4, 5] , 
    '학과' : ['CS' , 'AI' , 'AI' , 'CS'] ,
    '학점' : [2.8, 4.5, 1.9, 3.5] 
}

stu_frm = pd.DataFrame(data01)
major_frm = pd.DataFrame(data02)

pd.concat([stu_frm , major_frm] , axis = 1)
# Out:
#    학번  이름  학년  과목코드  학과   학점
# 0   1  하나   2     1  CS  2.8
# 1   2  두나   4     2  AI  4.5
# 2   3  세나   1     4  AI  1.9
# 3   4  네나   3     5  CS  3.5

# %%
stu_frm
# Out:
#    학번  이름  학년
# 0   1  하나   2
# 1   2  두나   4
# 2   3  세나   1
# 3   4  네나   3

# %%
major_frm
# Out:
#    과목코드  학과   학점
# 0     1  CS  2.8
# 1     2  AI  4.5
# 2     4  AI  1.9
# 3     5  CS  3.5

# %%
# dataframe 병합 함수 : pd.merge
# how = 'inner' -> 두 dataframe의 교집합을 반환 단 , 교집합이 있을경우
# pd.merge(stu_frm , major_frm)

# 교집합이 없을 경우, 교황 사망
pd.merge(stu_frm , major_frm , how = 'inner',left_on = '학번' , right_on  =  '과목코드')
# Out:
#    학번  이름  학년  과목코드  학과   학점
# 0   1  하나   2     1  CS  2.8
# 1   2  두나   4     2  AI  4.5
# 2   4  네나   3     4  AI  1.9

# %%
# how = 'outer' -> 두 dataframe의 합집합을 반환
pd.merge(stu_frm , major_frm , how = 'outer')

# %%
pd.merge(stu_frm , major_frm , how = 'left')

# %%
pd.merge(stu_frm , major_frm , how = 'right')

# %%
- 컬럼 인덱스가 다른 경우

# %%
import seaborn as sns
iris_frm = sns.load_dataset('iris')
print('type - ' , iris_frm )
# Out:
# type -       sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_frm.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data01 = {
    'species': ['setosa' , 'virginica' , 'virginica' ,'versicolor'] ,
    'sepal_length' : [5.1 , 4.9 , 4.7 , 4.6] 
}

data02 = {
    'species': ['setosa' , 'setosa' , 'virinca' ,'versicolor'] ,
    'sepal_width' : [3.5 , 3.0 , 3.2 , 3.1] 
}

iris01_frm = pd.DataFrame(data01)
iris02_frm = pd.DataFrame(data02)
display(iris01_frm)
print()
display(iris02_frm)
# Out:
#       species  sepal_length
# 0      setosa           5.1
# 1   virginica           4.9
# 2   virginica           4.7
# 3  versicolor           4.6
#       species  sepal_width
# 0      setosa          3.5
# 1      setosa          3.0
# 2     virinca          3.2
# 3  versicolor          3.1

# %%
# iris01_frm 과 iris02_frm 의 내부의 키가 중복되는 값이 있기 때문에 오류가 발생한다.
# how를 사용하지 말고 on 으로 사용하자.
# pd.merge(iris01_frm ,iris02_frm , how = 'species')
pd.merge(iris01_frm ,iris02_frm , on = 'species' , how = 'outer')
# Out:
#       species  sepal_length  sepal_width
# 0      setosa           5.1          3.5
# 1      setosa           5.1          3.0
# 2   virginica           4.9          NaN
# 3   virginica           4.7          NaN
# 4  versicolor           4.6          3.1
# 5     virinca           NaN          3.2

# %%
data01 = {
    'species': ['setosa' , 'virginica' , 'virginica' ,'versicolor'] ,
    'sepal_length' : [5.1 , 4.9 , 4.7 , 4.6] 
}

data02 = {
    'species': ['setosa' , 'setosa' , 'virinca' ,'versicolor'] ,
    'sepal_length' : [3.5 , 3.0 , 3.2 , 3.1] ,
    'petal_width' : [3.5 , 3.0 , 3.2 , 3.1] 
}

iris01_frm = pd.DataFrame(data01)
iris02_frm = pd.DataFrame(data02)
display(iris01_frm)
print()
display(iris02_frm)
# Out:
#       species  sepal_length
# 0      setosa           5.1
# 1   virginica           4.9
# 2   virginica           4.7
# 3  versicolor           4.6
#       species  sepal_length  petal_width
# 0      setosa           3.5          3.5
# 1      setosa           3.0          3.0
# 2     virinca           3.2          3.2
# 3  versicolor           3.1          3.1

# %%
# on -> 값이 중복되어야 한다. 중복만 된다면 복합 사용 가능

pd.merge(iris01_frm ,iris02_frm , on = ['species'] , how = 'outer')
# Out:
#       species  sepal_length_x  sepal_length_y  petal_width
# 0      setosa             5.1             3.5          3.5
# 1      setosa             5.1             3.0          3.0
# 2   virginica             4.9             NaN          NaN
# 3   virginica             4.7             NaN          NaN
# 4  versicolor             4.6             3.1          3.1
# 5     virinca             NaN             3.2          3.2

# %% [markdown]
# - merge : 열 병합
# - 인덱스를 기준으로 merge: left_index , right_index

# %%
sample_frm01 = pd.DataFrame({
    'city' : ['seoul' , 'seoul' ,'seoul' , 'kwangju', 'kwangju'] ,
    'year' : [2010 , 2050 , 2020 , 2018 , 2022] ,
    'pop'  : [100 , 200 , 300 , 400 ,500]
})
sample_frm01
# Out:
#       city  year  pop
# 0    seoul  2010  100
# 1    seoul  2050  200
# 2    seoul  2020  300
# 3  kwangju  2018  400
# 4  kwangju  2022  500

# %%
# 다중 인덱스 정의

sample_frm02 = pd.DataFrame(np.arange(12).reshape(6,2) ,
                           columns = ['feature01' , 'feature02'], 
                           index   = [['seoul' , 'seoul' , 'kwangju', 'kwangju', 'kwangju', 'kwangju'] , 
                                      [2010 , 2050 , 2020 , 2018 , 2022 , 2021]])
sample_frm02
# Out:
#               feature01  feature02
# seoul   2010          0          1
#         2050          2          3
# kwangju 2020          4          5
#         2018          6          7
#         2022          8          9
#         2021         10         11

# %%
# merge는 같은 칼럼이 없기 때문에 일반적으로는 병합되지 않는다.
# pd.merge(sample_frm01 , sample_frm02 , left_index = True , right_index = True )

pd.merge(sample_frm01 , sample_frm02 , right_index = True , left_on = ['city' , 'year'])
# Out:
#       city  year  pop  feature01  feature02
# 0    seoul  2010  100          0          1
# 1    seoul  2050  200          2          3
# 3  kwangju  2018  400          6          7
# 4  kwangju  2022  500          8          9

# %%
data01 = {
    '학번' : [1, 2, 3, 4] , 
    '이름' : ['하나' , '두나' , '세나' , '네나'] ,
    '학년' : [2, 4, 1, 3] 
}

data02 = {
    '과목코드' : [1, 2, 4, 5] , 
    '학과' : ['CS' , 'AI' , 'AI' , 'CS'] ,
    '학점' : [2.8, 4.5, 1.9, 3.5] 
}

stu_frm = pd.DataFrame(data01)
major_frm = pd.DataFrame(data02)

# %%
# 두 프레임의 인덱스가 동일하기 때문에 양측 left/right_index = True시 결합이 가능하다.

pd.merge(stu_frm , major_frm , left_index = True , right_index = True)
# Out:
#    학번  이름  학년  과목코드  학과   학점
# 0   1  하나   2     1  CS  2.8
# 1   2  두나   4     2  AI  4.5
# 2   3  세나   1     4  AI  1.9
# 3   4  네나   3     5  CS  3.5

# %%
# join 사용
stu_frm.join(major_frm , how = 'inner')
# Out:
#    학번  이름  학년  과목코드  학과   학점
# 0   1  하나   2     1  CS  2.8
# 1   2  두나   4     2  AI  4.5
# 2   3  세나   1     4  AI  1.9
# 3   4  네나   3     5  CS  3.5

# %% [markdown]
# - concat : 열 인덱스와 인덱스를 기준으로 하지않고 단순한 데이터 연결

# %%
pd.concat([pd.Series([0,1]) , pd.Series([2,3,4,5])])
# Out:
# 0    0
# 1    1
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
pd.concat([stu_frm , major_frm] , axis = 1)
# Out:
#    학번  이름  학년  과목코드  학과   학점
# 0   1  하나   2     1  CS  2.8
# 1   2  두나   4     2  AI  4.5
# 2   3  세나   1     4  AI  1.9
# 3   4  네나   3     5  CS  3.5

# %% [markdown]
# ## 연습

# %%
file_path = 'C:/Users/a/Documents/SQL/data/pandas/stock_price.xlsx'
stock_frm01 = pd.read_excel(file_path)
stock_frm01
# Out:
#        id stock_name          value   price
# 0  128940       한미약품   59385.666667  421000
# 1  130960     CJ E&M   58540.666667   98900
# 2  138250      엔에스쇼핑   14558.666667   13200
# 3  139480        이마트  239230.833333  254500
# 4  142280     녹십자엠에스     468.833333   10200
# 5  145990        삼양사   82750.000000   82000
# 6  185750        종근당   40293.666667  100500
# 7  192400      쿠쿠홀딩스  179204.666667  177500
# 8  199800         툴젠   -2514.333333  115400
# 9  204210     모두투어리츠    3093.333333    3475

# %%
file_path = 'C:/Users/a/Documents/SQL/data/pandas/stock_valuation.xlsx'
stock_frm02 = pd.read_excel(file_path)
stock_frm02
# Out:
#        id       name           eps     bps        per       pbr
# 0  130960     CJ E&M   6301.333333   54068  15.695091  1.829178
# 1  136480         하림    274.166667    3551  11.489362  0.887074
# 2  138040    메리츠금융지주   2122.333333   14894   6.313806  0.899691
# 3  139480        이마트  18268.166667  295780  13.931338  0.860437
# 4  145990        삼양사   5741.000000  108090  14.283226  0.758627
# 5  161390      한국타이어   5648.500000   51341   7.453306  0.820007
# 6  181710  NHN엔터테인먼트   2110.166667   78434  30.755864  0.827447
# 7  185750        종근당   3990.333333   40684  25.185866  2.470259
# 8  204210     모두투어리츠     85.166667    5335  40.802348  0.651359
# 9  207940   삼성바이오로직스   4644.166667   60099  89.790059  6.938551

# %%
pd.merge(stock_frm01 , stock_frm02 , how = 'outer')
# Out:
#         id stock_name          value     price       name           eps  \
# 0   128940       한미약품   59385.666667  421000.0        NaN           NaN
# 1   130960     CJ E&M   58540.666667   98900.0     CJ E&M   6301.333333
# 2   138250      엔에스쇼핑   14558.666667   13200.0        NaN           NaN
# 3   139480        이마트  239230.833333  254500.0        이마트  18268.166667
# 4   142280     녹십자엠에스     468.833333   10200.0        NaN           NaN
# 5   145990        삼양사   82750.000000   82000.0        삼양사   5741.000000
# 6   185750        종근당   40293.666667  100500.0        종근당   3990.333333
# 7   192400      쿠쿠홀딩스  179204.666667  177500.0        NaN           NaN
# 8   199800         툴젠   -2514.333333  115400.0        NaN           NaN
# 9   204210     모두투어리츠    3093.333333    3475.0     모두투어리츠     85.166667
# 10  136480        NaN            NaN       NaN         하림    274.166667
# 11  138040        NaN            NaN       NaN    메리츠금융지주   2122.333333
# ...

# %%
pd.merge(stock_frm01 , stock_frm02 , how = 'inner')
# Out:
#        id stock_name          value   price    name           eps     bps  \
# 0  130960     CJ E&M   58540.666667   98900  CJ E&M   6301.333333   54068
# 1  139480        이마트  239230.833333  254500     이마트  18268.166667  295780
# 2  145990        삼양사   82750.000000   82000     삼양사   5741.000000  108090
# 3  185750        종근당   40293.666667  100500     종근당   3990.333333   40684
# 4  204210     모두투어리츠    3093.333333    3475  모두투어리츠     85.166667    5335
#
#          per       pbr
# 0  15.695091  1.829178
# 1  13.931338  0.860437
# 2  14.283226  0.758627
# 3  25.185866  2.470259
# 4  40.802348  0.651359

# %%
pd.merge(stock_frm01 , stock_frm02 , how = 'right')
# Out:
#        id stock_name          value     price       name           eps  \
# 0  130960     CJ E&M   58540.666667   98900.0     CJ E&M   6301.333333
# 1  136480        NaN            NaN       NaN         하림    274.166667
# 2  138040        NaN            NaN       NaN    메리츠금융지주   2122.333333
# 3  139480        이마트  239230.833333  254500.0        이마트  18268.166667
# 4  145990        삼양사   82750.000000   82000.0        삼양사   5741.000000
# 5  161390        NaN            NaN       NaN      한국타이어   5648.500000
# 6  181710        NaN            NaN       NaN  NHN엔터테인먼트   2110.166667
# 7  185750        종근당   40293.666667  100500.0        종근당   3990.333333
# 8  204210     모두투어리츠    3093.333333    3475.0     모두투어리츠     85.166667
# 9  207940        NaN            NaN       NaN   삼성바이오로직스   4644.166667
#
#       bps        per       pbr
# 0   54068  15.695091  1.829178
# 1    3551  11.489362  0.887074
# 2   14894   6.313806  0.899691
# 3  295780  13.931338  0.860437
# ...

# %%
pd.merge(stock_frm01 , stock_frm02 , how = 'left')
# Out:
#        id stock_name          value   price    name           eps       bps  \
# 0  128940       한미약품   59385.666667  421000     NaN           NaN       NaN
# 1  130960     CJ E&M   58540.666667   98900  CJ E&M   6301.333333   54068.0
# 2  138250      엔에스쇼핑   14558.666667   13200     NaN           NaN       NaN
# 3  139480        이마트  239230.833333  254500     이마트  18268.166667  295780.0
# 4  142280     녹십자엠에스     468.833333   10200     NaN           NaN       NaN
# 5  145990        삼양사   82750.000000   82000     삼양사   5741.000000  108090.0
# 6  185750        종근당   40293.666667  100500     종근당   3990.333333   40684.0
# 7  192400      쿠쿠홀딩스  179204.666667  177500     NaN           NaN       NaN
# 8  199800         툴젠   -2514.333333  115400     NaN           NaN       NaN
# 9  204210     모두투어리츠    3093.333333    3475  모두투어리츠     85.166667    5335.0
#
#          per       pbr
# 0        NaN       NaN
# 1  15.695091  1.829178
# 2        NaN       NaN
# 3  13.931338  0.860437
# ...

# %%
stock_frm01['stock_name'].unique()
# Out:
# array(['한미약품', 'CJ E&M', '엔에스쇼핑', '이마트', '녹십자엠에스', '삼양사', '종근당', '쿠쿠홀딩스',
#        '툴젠', '모두투어리츠'], dtype=object)

# %%
set(stock_frm01['stock_name'].unique()) - set(stock_frm02['name'].unique())
# Out:
# {'녹십자엠에스', '엔에스쇼핑', '쿠쿠홀딩스', '툴젠', '한미약품'}

# %%
pd.merge(stock_frm01 , stock_frm02 , how = 'inner').drop('stock_name' , axis = 1)
# Out:
#        id          value   price    name           eps     bps        per  \
# 0  130960   58540.666667   98900  CJ E&M   6301.333333   54068  15.695091
# 1  139480  239230.833333  254500     이마트  18268.166667  295780  13.931338
# 2  145990   82750.000000   82000     삼양사   5741.000000  108090  14.283226
# 3  185750   40293.666667  100500     종근당   3990.333333   40684  25.185866
# 4  204210    3093.333333    3475  모두투어리츠     85.166667    5335  40.802348
#
#         pbr
# 0  1.829178
# 1  0.860437
# 2  0.758627
# 3  2.470259
# 4  0.651359

# %% [markdown]
# #### 참고
# #### https://yganalyst.github.io/data_handling/Pd_12/
