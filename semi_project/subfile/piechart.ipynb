# %%
# 출처 : https://wikidocs.net/92114

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()
# 우선 각 영역의 비율과 이름을 ratio와 labels로 지정해주고,
# pie() 함수에 순서대로 입력합니다.
# autopct는 부채꼴 안에 표시될 숫자의 형식을 지정합니다. 소수점 한자리까지 표시하도록 설정했습니다.

# %% [markdown]
# ### 시작 각도와 방향

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False)
plt.show()

# startangle는 부채꼴이 그려지는 시작 각도를 설정합니다.
# 디폴트는 0도 (양의 방향 x축)로 설정되어 있습니다.
# counterclock=False로 설정하면 시계 방향 순서로 부채꼴 영역이 표시됩니다.

# %% [markdown]
# ### 중심에서 벗어나는 정도

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0, 0.10, 0, 0.10]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# explode는 부채꼴이 파이 차트의 중심에서 벗어나는 정도를 설정합니다.

# %% [markdown]
# ### 그림자 나타내기

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]
plt.title('title', size= 15, rotation = 45)
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True)
plt.show()

# %% [markdown]
# ### 색상 지정

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['silver', 'gold', 'whitesmoke', 'lightgray']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()

# colors를 사용하면 각 영역의 색상을 자유롭게 지정할 수 있습니다.
# silver’, ‘gold’, ‘lightgray’, ‘whitesmoke’ 등 색상의 이름

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()

# %% [markdown]
# ### 부채꼴 스타일

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# wedgeprops는 부채꼴 영역의 스타일을 설정합니다.
# wedgeprops 딕셔너리의 ‘width’, ‘edgecolor’, ‘linewidth’ 키를 이용해서 각각 부채꼴 영역의 너비 (반지름에 대한 비율),

# %% [markdown]
# ### 기타
# - 출처: https://rfriend.tistory.com/412 [R, Python 분석과 프로그래밍의 친구 (by R Friend):티스토리]

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]

# %%
group_names = ['Group_A', 'Group_B', 'Group_C']
group_sizes = [95, 54, 25]
group_colors = ['yellowgreen', 'lightskyblue', 'lightcoral']
group_explodes = (0.1, 0, 0) # explode 1st slice

# %%
plt.pie(group_sizes,
        explode=group_explodes,
        labels=group_names,
        colors=group_colors,
        autopct='%1.2f%%', # second decimal place
        shadow=True,
        startangle=90, 
        textprops={'fontsize': 14}) 
# text font sizeplt.axis('equal') 
#  equal length of X and Y axisplt.title('Pie Chart of Market Share', fontsize=20)
plt.show()
# Out:
#   Input In [23]
#     startangle=90,
#                   ^
# SyntaxError: invalid non-printable character U+00A0
