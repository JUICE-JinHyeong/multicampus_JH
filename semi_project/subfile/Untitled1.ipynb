# %%
import json as j
import folium
import pandas as pd

# %%
single_02 = pd.read_csv('C:/Users/PiGiraffe0/Documents/SQL/semi_project/data/int_02_worldmap_data02.csv' , encoding = 'euc-kr')


single_02
# Out:
#     Unnamed: 0       지역     2017     2018     2019     2020     2021
# 0            0       전국  5618677  5848594  6147516  6643354  7165788
# 1            1    서울특별시  1180540  1229421  1299787  1390701  1489893
# 2            2    부산광역시   388899   404408   423227   455207   487362
# 3            3    대구광역시   259525   269903   284416   304543   326866
# 4            4    인천광역시   266434   275898   297865   324841   355657
# 5            5    광주광역시   171424   174614   182364   193948   212385
# 6            6    대전광역시   188136   195544   205165   228842   240932
# 7            7    울산광역시   107497   110236   116015   122848   133061
# 8            8  세종특별자치시    31472    35763    39078    43577    45706
# 9            9      경기도  1124541  1197586  1290893  1406010  1543100
# 10          10      강원도   199645   206295   208857   231371   245012
# 11          11     충청북도   195186   204109   215196   236208   252251
# 12          12     충청남도   259727   270497   280773   304973   327432
# ...

# %%
# series 혹은 dataframe 
pop_01 = single_02[['지역' , '2017' ,'2021']].drop([0])
for i in range(1,18) :
    pop_01 = pop_01.rename(index = { i : i-1})

pop_01.rename(columns = {'지역' : 'district'})
pop_01 = pop_01.rename(columns = {'지역' : 'district'})

pop_01.info()
pop_01
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 16
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   district  17 non-null     object
#  1   2017      17 non-null     int64
#  2   2021      17 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 544.0+ bytes
#    district     2017     2021
# 0     서울특별시  1180540  1489893
# 1     부산광역시   388899   487362
# 2     대구광역시   259525   326866
# 3     인천광역시   266434   355657
# 4     광주광역시   171424   212385
# 5     대전광역시   188136   240932
# 6     울산광역시   107497   133061
# 7   세종특별자치시    31472    45706
# 8       경기도  1124541  1543100
# 9       강원도   199645   245012
# 10     충청북도   195186   252251
# 11     충청남도   259727   327432
# 12     전라북도   227600   276153
# 13     전라남도   232022   274108
# 14     경상북도   346998   416697
# 15     경상남도   370293   450490
# 16  제주특별자치도    68738    88683

# %%
color_01 = pd.read_excel('C:/Users/PiGiraffe0/Documents/SQL/semi_project/data/color.xlsx')
color_01
# Out:
#    color_code
# 0     #A52A2A
# 1     #BC8F8F
# 2     #FF4500
# 3     #F4A460
# 4     #FFEFD5
# 5     #F0E68C
# 6     #9ACD32
# 7     #7FFF00
# 8     #66CDAA
# 9     #20B2AA
# 10    #008B8B
# 11    #00BFFF
# 12    #1E90FF
# 13    #0000CD
# 14    #9932CC
# 15    #FF69B4
# 16    #DC143C

# %%
from matplotlib import font_manager, rc
import platform 

if platform.system() == 'Windows': 
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
else: 
    print('Check your OS system')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values)
plt.xticks(x, years)

plt.show()

# %%
x = np.arange(17)
colors = list(color_01['color_code'])
plt.figure(figsize=(20, 10))

plt.ylabel('1인 가구 수 (단위 : 만)')
plt.xlabel('지역')
plt.bar(x, pop_01_little , color = colors)
plt.xticks(x, pop_01['district'])
plt.show()

# %%
pop_01_little = data_03['2017']/10000
pop_01_little = data_03_little.astype(int)
pop_01_little
# Out:
# 0     118
# 1      38
# 2      25
# 3      26
# 4      17
# 5      18
# 6      10
# 7       3
# 8     112
# 9      19
# 10     19
# 11     25
# 12     22
# 13     23
# 14     34
# 15     37
# 16      6
# Name: 2017, dtype: int32

# %%
list(color_01['color_code'])
# Out:
# ['#A52A2A',
#  '#BC8F8F',
#  '#FF4500',
#  '#F4A460',
#  '#FFEFD5',
#  '#F0E68C',
#  '#9ACD32',
#  '#7FFF00',
#  '#66CDAA',
#  '#20B2AA',
#  '#008B8B',
#  '#00BFFF',
#  '#1E90FF',
#  '#0000CD',
#  '#9932CC',
#  '#FF69B4',
#  '#DC143C']

# %%
lst_a = []
for i in range(0,16) :
    lst_a.extend(pop_01[['district']].loc[i].to_list())
    
lst_a
# Out:
# ['서울특별시',
#  '부산광역시',
#  '대구광역시',
#  '인천광역시',
#  '광주광역시',
#  '대전광역시',
#  '울산광역시',
#  '세종특별자치시',
#  '경기도',
#  '강원도',
#  '충청북도',
#  '충청남도',
#  '전라북도',
#  '전라남도',
#  '경상북도',
#  '경상남도']
